# %%
import pandas as pd
import uuid

# %%
# read datasets for US, Canada, Japan, India, and Brazil
df_br = pd.read_csv('datasets\BR_youtube_trending_data.csv')
df_ca = pd.read_csv('datasets\CA_youtube_trending_data.csv')
df_in = pd.read_csv('datasets\IN_youtube_trending_data.csv')
df_jp = pd.read_csv('datasets\JP_youtube_trending_data.csv')
df_us = pd.read_csv('datasets\\US_youtube_trending_data.csv')

# %%
# add country code and information
df_br['countryName'] = 'Brazil'
df_br['countryCode'] = 1

df_ca['countryName'] = 'Canada'
df_ca['countryCode'] = 2

df_in['countryName'] = 'India'
df_in['countryCode'] = 3

df_jp['countryName'] = 'Japan'
df_jp['countryCode'] = 4

df_us['countryName'] = 'US'
df_us['countryCode'] = 5

# %%
df_br = df_br.tail(1000)
df_ca = df_ca.tail(1000)
df_in = df_in.tail(1000)
df_jp = df_jp.tail(1000)
df_us = df_us.tail(1000)

# %%
df_merged = pd.concat([df_br, df_ca, df_in, df_jp, df_us],ignore_index=True)

# %%
df_merged.head(5)
# Out:
#       video_id                                              title  \
# 0  _jICVrlX8h8  PERÚ vs. ARGENTINA [0-2] | RESUMEN | ELIMINATO...
# 1  J5L00K9u3x8  NÃO TEMOS UM TIME! - Galvão comenta o jogo da ...
# 2  cXGkoPb6LiA  DE FRENTE COM BLOGUEIRINHA: PRETA GIL - T2E25 ...
# 3  I3Rt23SUbVs  URUGUAI 2 X 0 BRASIL | MELHORES MOMENTOS | ELI...
# 4  WGuqNxHnCtw                                   O FUTURO DO FLOW
#
#             publishedAt                 channelId  channelTitle  categoryId  \
# 0  2023-10-18T04:36:56Z  UCzU8-lZlRfkV3nj0RzAZdrQ      CONMEBOL          17
# 1  2023-10-18T04:22:19Z  UCm1_S0MCQYO9EWukQoAcRFA      Canal GB          17
# 2  2023-10-17T01:00:55Z  UCF8MQYobXcHejWAaet4nSxA  Blogueirinha          24
# 3  2023-10-18T02:09:36Z  UCgCKagVhzGnZcuP9bSMgMCg            ge          17
# 4  2023-10-17T00:00:29Z  UC4ncvgh5hFr5O83MH7-jRJg  Flow Podcast          22
#
#           trending_date                                               tags  \
# 0  2023-10-18T00:00:00Z  fútbol|pelota|gol|copa|libertadores|sudamerica...
# 1  2023-10-18T00:00:00Z  galvão|globo|galvao bueno|futebol|galvão bueno...
# 2  2023-10-18T00:00:00Z  blogueirinha|de frente com blogueirinha|bruno ...
# 3  2023-10-18T00:00:00Z  rodada|Vitória|vitória|empate|derrota|defesa|t...
# 4  2023-10-18T00:00:00Z  flowpodcast777|FLOW|FLOW PODCAST|PODCAST|IGOR|...
#
#    view_count  likes  dislikes  comment_count  \
# 0     1540752      0         0           2247
# 1      183673  22797         0           2946
# 2      898616  63531         0           3296
# 3      795551  27885         0           6907
# 4      528175  39673         0            952
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/_jICVrlX8h8/default.jpg              False
# 1  https://i.ytimg.com/vi/J5L00K9u3x8/default.jpg              False
# 2  https://i.ytimg.com/vi/cXGkoPb6LiA/default.jpg              False
# 3  https://i.ytimg.com/vi/I3Rt23SUbVs/default.jpg              False
# 4  https://i.ytimg.com/vi/WGuqNxHnCtw/default.jpg              False
#
#    ratings_disabled                                        description  \
# 0              True  ¡Argentina pisó fuerte en Lima y se llevó otro...
# 1             False  Inscreva-se no Canal GB e ative o sininho para...
# 2             False  Hoje é dia de receber ela que é suave como um ...
# 3             False  Brasil perde para o Uruguai, cai na tabela e v...
# 4             False  O Futuro do Flow, uma nova página, de uma hist...
#
#   countryName  countryCode
# 0      Brazil            1
# 1      Brazil            1
# 2      Brazil            1
# 3      Brazil            1
# 4      Brazil            1

# %%
# channel table
df_channel = df_merged[['channelId', 'channelTitle']]
df_channel = df_channel.drop_duplicates()
df_channel
# Out:
#                      channelId                  channelTitle
# 0     UCGfBwrCoi9ZJjKiUK8MmJNw                 Pietro Guedes
# 1     UCaO6TYtlC8U5ttz62hTrZgg             JYP Entertainment
# 2     UCoXZmVma073v5G1cW82UKkA                 As Irmãs Mota
# 3     UC6Xqz2pm50gDCORYztqhDpg          League of Legends BR
# 4     UCEWOoncsrmirqnFqxer9lmA  The Noite com Danilo Gentili
# ...                        ...                           ...
# 4867  UCvExuGSwx1Yw30dDY8JEJ3w                       TalkFCB
# 4869  UCwXeXBlXS4VWsllAk40tHRg                    DarellVEVO
# 4877  UC-PbLusIBd3ECYtvz-f0EcQ                     audiomack
# 4879  UCd3Llj2WWJh8ItfYl32eJ4Q                      YUNGBLUD
# 4883  UCO5EnkKW7tF6btDji2ii0jg                Cookiee Kawaii
#
# [1141 rows x 2 columns]

# %%
# category table
df_category = df_merged[['video_id', 'categoryId', 'tags']]
category_key = [str(uuid.uuid4()) for i in range(df_category.shape[0])]
df_category['category_key'] = category_key
df_category = df_category[['category_key', 'video_id', 'categoryId', 'tags']]
df_category
# Out:
# C:\Users\gxi87\AppData\Local\Temp/ipykernel_17724/1251647659.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_category['category_key'] = category_key
#                               category_key     video_id  categoryId  \
# 0     23805906-40f8-40af-aa46-0864ee7d0fa7  s9FH4rDMvds          22
# 1     6eb12b34-e798-4036-893e-f91c92b8798e  jbGRowa5tIk          10
# 2     db88c72d-b4be-4121-81cf-75bc751f811b  3EfkCrXKZNs          22
# 3     93f4b78a-e010-4302-a010-6255b83a20a9  gBjox7vn3-g          20
# 4     43a70a27-9634-4be6-8b80-cfe1867bb0cb  npoUGx7UW7o          23
# ...                                    ...          ...         ...
# 4995  4d41ca48-077c-44ea-bcac-9fd4ca885f0b  8QsH_xPQFqM          24
# 4996  37011fc1-3bc6-48f0-93ca-05d30539a120  jp47GeO6k6Q          17
# 4997  9bec4f66-d414-4498-b1c2-968cecebaac7  n_8hxS_7Vis          17
# 4998  c33fef98-f7a1-4250-b917-30d1977da046  FQnJRVn3QVk          24
# 4999  b254026b-4bb8-48f3-96a1-e6710e016c24  goOmZUwQYlA          24
#
#                                                    tags
# 0     pietro|guedes|ingrid|ohara|pingrid|vlog|amigos...
# 1     JYP Entertainment|JYP|ITZY|있지|ITZY Video|ITZY ...
# 2     OH JULIANA PARÓDIA|MC Niack PARÓDIA|PARÓDIAS|A...
# 3     Riot|Riot Games|League of Legends|lol|trailer|...
# 4     The Noite|The Noite com Danilo Gentili|Danilo ...
# ...                                                 ...
# 4995  Aliya Janell|Aliya Janell choreography|queens ...
# 4996  LeBron James|LA Lakers|House of Highlights|ESP...
# 4997  fox|fox sports|fs1|fox sports 1|undisputed|ski...
# 4998  movie|trailer|reaction|review|chill|zone|dylan...
# 4999                                             [None]
#
# [5000 rows x 4 columns]

# %%
# video table
df_video = df_merged[['video_id', 'channelId', 'trending_date', 'title', 'thumbnail_link', 'description']]
df_video
# Out:
#          video_id                 channelId         trending_date  \
# 0     s9FH4rDMvds  UCGfBwrCoi9ZJjKiUK8MmJNw  2020-08-12T00:00:00Z
# 1     jbGRowa5tIk  UCaO6TYtlC8U5ttz62hTrZgg  2020-08-12T00:00:00Z
# 2     3EfkCrXKZNs  UCoXZmVma073v5G1cW82UKkA  2020-08-12T00:00:00Z
# 3     gBjox7vn3-g  UC6Xqz2pm50gDCORYztqhDpg  2020-08-12T00:00:00Z
# 4     npoUGx7UW7o  UCEWOoncsrmirqnFqxer9lmA  2020-08-12T00:00:00Z
# ...           ...                       ...                   ...
# 4995  8QsH_xPQFqM  UC7Ul2k3EhfIHE2RFvjoMorA  2020-08-16T00:00:00Z
# 4996  jp47GeO6k6Q  UC3L9XPe0_FGfRG-CMGtBvFg  2020-08-16T00:00:00Z
# 4997  n_8hxS_7Vis  UCLXzq85ijg2LwJWFrz4pkmw  2020-08-16T00:00:00Z
# 4998  FQnJRVn3QVk  UCF_votze88WRDSEREe9s3aQ  2020-08-16T00:00:00Z
# 4999  goOmZUwQYlA  UCf1JAjcoBlCRi4pHG2k_W7w  2020-08-16T00:00:00Z
#
#                                                   title  \
# 0        LEVEI UM FORA? FINGI ESTAR APAIXONADO POR ELA!
# 1                             ITZY “Not Shy” M/V TEASER
# 2                         Oh Juliana PARÓDIA - MC Niack
# 3      Contos de Runeterra: Targon | A Estrada Tortuosa
# 4     Entrevista com Thammy Miranda | The Noite (10/...
# ...                                                 ...
# 4995  ALREADY | Black Is King | Aliya Janell | Kany ...
# 4996                    How Does He Get Away With This?
# 4997  Shannon reacts to Kyle Kuzma's game-winning sh...
# 4998  Watching Movie Trailers... Then Guessing Their...
# 4999                                               100k
#
#                                       thumbnail_link  \
# 0     https://i.ytimg.com/vi/s9FH4rDMvds/default.jpg
# 1     https://i.ytimg.com/vi/jbGRowa5tIk/default.jpg
# 2     https://i.ytimg.com/vi/3EfkCrXKZNs/default.jpg
# 3     https://i.ytimg.com/vi/gBjox7vn3-g/default.jpg
# 4     https://i.ytimg.com/vi/npoUGx7UW7o/default.jpg
# ...                                              ...
# 4995  https://i.ytimg.com/vi/8QsH_xPQFqM/default.jpg
# 4996  https://i.ytimg.com/vi/jp47GeO6k6Q/default.jpg
# 4997  https://i.ytimg.com/vi/n_8hxS_7Vis/default.jpg
# 4998  https://i.ytimg.com/vi/FQnJRVn3QVk/default.jpg
# 4999  https://i.ytimg.com/vi/goOmZUwQYlA/default.jpg
#
#                                             description
# 0     Salve rapaziada, neste vídeo me declarei pra e...
# 1     ITZY Not Shy M/V[ITZY Official] https://www.yo...
# 2     Se inscrevam meus amores! 📬 Quer nos mandar al...
# 3     Você se unirá aos Lunari e aos Solari em Targo...
# 4     Danilo Gentili recebe Thammy Miranda. Após pas...
# ...                                                 ...
# 4995  Had the pleasure of learning from this queen n...
# 4996  🔥GET YOUR EXCLUSIVE BASKETBALL SHORTS NOW! htt...
# 4997  LeBron and the Lakers finally snapped their 3-...
# 4998  Welcome to the Chill Zone, where we chill and ...
# 4999                                             thanks
#
# [5000 rows x 6 columns]

# %%
# table for stats at published date
df_published_stats = df_merged[['publishedAt', 'video_id', 'view_count', 'likes', 'dislikes', 'comment_count', 'comments_disabled', 'ratings_disabled']]
df_published_stats['publishedAt'] = df_published_stats['publishedAt'].str[:13]
df_published_stats
# Out:
# C:\Users\gxi87\AppData\Local\Temp/ipykernel_17724/1095780626.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_published_stats['publishedAt'] = df_published_stats['publishedAt'].str[:13]
#         publishedAt     video_id  view_count   likes  dislikes  comment_count  \
# 0     2020-08-11T22  s9FH4rDMvds      263835   85095       487           4500
# 1     2020-08-11T15  jbGRowa5tIk     6000070  714310     15176          31040
# 2     2020-08-10T14  3EfkCrXKZNs     2296748   39761      5484              0
# 3     2020-08-11T15  gBjox7vn3-g      300510   46222       242           2748
# 4     2020-08-11T20  npoUGx7UW7o      327235   22059      3972           2751
# ...             ...          ...         ...     ...       ...            ...
# 4995  2020-08-10T19  8QsH_xPQFqM      443572   40384       388           1334
# 4996  2020-08-09T18  jp47GeO6k6Q     1631138   65497      1806           7393
# 4997  2020-08-11T16  n_8hxS_7Vis      592569    7456       318           1687
# 4998  2020-08-10T16  FQnJRVn3QVk      504902   48747       266           3422
# 4999  2020-08-11T03  goOmZUwQYlA      348679   33010       258            915
#
#       comments_disabled  ratings_disabled
# 0                 False             False
# 1                 False             False
# 2                  True             False
# 3                 False             False
# 4                 False             False
# ...                 ...               ...
# 4995              False             False
# 4996              False             False
# 4997              False             False
# 4998              False             False
# 4999              False             False
#
# [5000 rows x 8 columns]

# %%
df_country = df_merged[['countryName', 'countryCode']].drop_duplicates()
df_country
# Out:
#      countryName  countryCode
# 0         Brazil            1
# 1000      Canada            2
# 2000       India            3
# 3000       Japan            4
# 4000          US            5

# %%
import numpy as np
c = df_category.to_numpy()
for i in c:
    print(tuple(i))
    break
# Out:
# ('23805906-40f8-40af-aa46-0864ee7d0fa7', 's9FH4rDMvds', 22, 'pietro|guedes|ingrid|ohara|pingrid|vlog|amigos|jully|molina|mansão|mansao|dos|youtubers|gkhouse')

# %%
# file_name = 'nddp.sql'

# with open(file_name, 'w') as file:
#     file.write('INSERT INTO \'\'')
